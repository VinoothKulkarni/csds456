# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

foursquareusers = pd.read_csv("drive/My Drive/Data_Privacy_Project/foursquareusers.csv")
twitterusers = pd.read_csv("drive/My Drive/Data_Privacy_Project/twitterusers.csv")
tipofuser = pd.read_csv("drive/My Drive/Data_Privacy_Project/tipofuser.csv")
tweetofuser = pd.read_csv("drive/My Drive/Data_Privacy_Project/tweetofuser.csv")
foursquareusers['location'].value_counts()
# Out:
# Kuwait, 02                96
# New York, NY              69
# Singapore                 58
# Istanbul                  44
# Kuwait City, Al Asimah    39
#                           ..
# Pasadena, TX               1
# Mersin, 33                 1
# Qortuba                    1
# El Paso, Texas             1
# Rutherford, NJ             1
# Name: location, Length: 2066, dtype: int64

# %%
foursquareusers['location'].isna().sum().sum()
# Out:
# 294

# %%
twitterusers['location'].isna().sum().sum()
# Out:
# 935

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
# location = geolocator.geocode("16800 Van Aken Blvd")
location = geolocator.geocode("Istanbul")
print(location.address)
print((location.latitude, location.longitude))
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# İstanbul, Fatih, İstanbul, Marmara Bölgesi, 34126, Türkiye
# (41.0091982, 28.9662187)
